# %%
import pandas as pd 

df = pd.read_csv('app_w_data.csv')
df.head()
# Out:
#    Unnamed: 0      ID        Province  Aboriginal  Education  House_size  \
# 0           0  100000       "Alberta"           0       4996        2498
# 1           1  100001  "Saskatchewan"           0        524         524
# 2           2  100002        "Quebec"           0       3960        1320
# 3           3  100003       "Ontario"           0       4826        4826
# 4           4  100004        "Quebec"           0       8648       34592
#
#    Gender  Age_gp  House_type   Lang  ...  Internet_income  Non_onlineShopper  \
# 0    4996    7494        7494   2498  ...                0                  0
# 1     524    2620        1572    524  ...                0                  0
# 2    1320    6600        3960   3960  ...                0                  0
# 3    4826    9652        4826   2413  ...                0                  0
# 4    8648    8648        8648  17296  ...                0                  0
#
# ...

# %%
pd.set_option('display.max_rows', 1500)
pd.set_option('display.max_columns', 1500)
pd.set_option('display.width', 1000)


df.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13810 entries, 0 to 13809
# Data columns (total 186 columns):
#  #    Column                     Dtype
# ---   ------                     -----
#  0    Unnamed: 0                 int64
#  1    ID                         int64
#  2    Province                   object
#  3    Aboriginal                 int64
#  4    Education                  int64
#  5    House_size                 int64
#  6    Gender                     int64
#  7    Age_gp                     int64
#  8    House_type                 int64
#  9    Lang                       int64
#  10   Employment                 int64
#  11   Current_student            int64
#  12   immigrant                  int64
#  13   IN_personal_use            int64
#  14   IN_household_yn            int64
#  15   IN_work                    int64
#  16   IN_school                  int64
#  17   IN_library                 int64
#  18   IN_public                  int64
# ...

# %%
corr_matrix = df.corr()
corr_matrix.head()
# Out:
#             Unnamed: 0        ID  Aboriginal  Education  House_size    Gender    Age_gp  House_type      Lang  Employment  Current_student  immigrant  IN_personal_use  IN_household_yn   IN_work  IN_school  IN_library  IN_public  IN_business   IN_home  IN_otherhome  hours_online  DVC_SMPH  DVC_lptp  DVC_tblt    DVC_pc  DVC_other  COM_email    COM_IM   COM_SNS  COM_vidcall  COM_dating  COM_contentsharing  COM_blog  INFO_news  INFO_location  INFO_research  ENT_music  ENT_podcast  ENT_stream  ENT_vids  ENT_sports    ENT_TV  ENT_book  ENT_game  ENT_gamble  ECOM_newbuy  ECOM_usedgoods  ECOM_tradegood  ECOM_stockfin  ACT_jobsearch  ACT_onlineBanking  ACT_wallet  ACT_train  ACT_trainformal  ACT_donate  ACT_appointmnet  ACT_schedule  VICT_bullying  VICT_harassement  VICT_discrimination  VICT_stalking  VICT_picmisuse  VICT_idfraud  VICT_other  VICT_none  SM_personal  SM_USE_frq_allday  SM_USE_frq_bedtime  SM_USE_frq_TV  SM_USE_frq_dinner  SM_USE_buy  SM_USE_sell  SM_USE_appointment  \
# ...

# %%
corr_matrix.to_csv('correlation_matrix.csv')

# %%
print(df.columns.tolist())
# Out:
# ['Unnamed: 0', 'ID', 'Province', 'Aboriginal', 'Education', 'House_size', 'Gender', 'Age_gp', 'House_type', 'Lang', 'Employment', 'Current_student', 'immigrant', 'IN_personal_use', 'IN_household_yn', 'IN_work', 'IN_school', 'IN_library', 'IN_public', 'IN_business', 'IN_home', 'IN_otherhome', 'hours_online', 'DVC_SMPH', 'DVC_lptp', 'DVC_tblt', 'DVC_pc', 'DVC_other', 'COM_email', 'COM_IM', 'COM_SNS', 'COM_vidcall', 'COM_dating', 'COM_contentsharing', 'COM_blog', 'INFO_news', 'INFO_location', 'INFO_research', 'ENT_music', 'ENT_podcast', 'ENT_stream', 'ENT_vids', 'ENT_sports', 'ENT_TV', 'ENT_book', 'ENT_game', 'ENT_gamble', 'ECOM_newbuy', 'ECOM_usedgoods', 'ECOM_tradegood', 'ECOM_stockfin', 'ACT_jobsearch', 'ACT_onlineBanking', 'ACT_wallet', 'ACT_train', 'ACT_trainformal', 'ACT_donate', 'ACT_appointmnet', 'ACT_schedule', 'VICT_bullying', 'VICT_harassement', 'VICT_discrimination', 'VICT_stalking', 'VICT_picmisuse', 'VICT_idfraud', 'VICT_other', 'VICT_none', 'SM_personal', 'SM_USE_frq_alld
# ...

# %%
x1_ = ['Province', 'Aboriginal', 'Education', 'House_size', 'Gender', 'Age_gp']
x1_2= ['House_type', 'Lang', 'Employment', 'Current_student', 'immigrant']
x2_ = ['IN_personal_use', 'IN_household_yn', 'IN_work', 'IN_school', 'IN_library']
x2_2= ['IN_public', 'IN_business', 'IN_home', 'IN_otherhome']
x3_ = ['hours_online', 'DVC_SMPH', 'DVC_lptp', 'DVC_tblt', 'DVC_pc', 'DVC_other']
x4_ = ['COM_email', 'COM_IM', 'COM_SNS', 'COM_vidcall', 'COM_dating', 'COM_contentsharing', 'COM_blog']
x5_ = ['INFO_news', 'INFO_location', 'INFO_research'] 
x6_ = ['ENT_music', 'ENT_podcast','ENT_stream', 'ENT_vids', 'ENT_sports']
x6_2= ['ENT_TV', 'ENT_book', 'ENT_game', 'ENT_gamble']
x7_ = ['ACT_jobsearch', 'ACT_onlineBanking', 'ACT_wallet', 'ACT_train']
x7_2= ['ACT_trainformal', 'ACT_donate', 'ACT_appointmnet', 'ACT_schedule']
x8_ = ['VICT_bullying', 'VICT_harassement', 'VICT_discrimination', 'VICT_stalking']
x8_2= ['VICT_picmisuse', 'VICT_idfraud', 'VICT_other', 'VICT_none']
x9_ = ['ECOM_newbuy', 'ECOM_usedgoods', 'ECOM_tradegood', 'ECOM_stockfin']
x10_ = ['SM_personal', 'SM_USE_frq_allday', 'SM_USE_frq_bedtime', 'SM_USE_frq_TV', 'SM_USE_frq_dinner']
x11_ = ['SM_USE_buy', 'SM_USE_sell', 'SM_USE_appointment', 'SM_USE_stream', 'SM_USE_listen']
x11_2= ['SM_USE_wallet','SM_USE_jobsearch', 'SM_USE_search', 'SM_USE_fitness', 'SNS_accounts', 'SNS_reguse'] 
x13_ = ['VID_streaming_hours', 'NEWS_pay', 'NEWS_pay_digprint', 'NEWS_pay_occasional'] 
x14_ = ['SEC_userpass', 'SEC_secQ', 'SEC_twostep', 'SEC_bio', 'SEC_passmanager', 'SEC_other', 'SEC_none_available']
x15_ = ['SEC_idtheft', 'SEC_infoabuse', 'SEC_fraudcommunication', 'SEC_hack', 'SEC_payfraud', 'SEC_ransom', 'SEC_issue_other'] 
x16_ = ['SEC_update', 'SEC_antivirus', 'SEC_mobile_update', 'SEC_mobile_antivirus']
x17_ = ['Skill_free', 'Skill_friends', 'Skill_community', 'Skill_public', 'Skill_paid', 'Skill_employer', 'Skill_none']
x18_ = ['ECOM_music', 'ECOM_vid', 'ECOM_ebook', 'ECOM_podcast', 'ECOM_news']
x19_ = ['ECOM_giftcard', 'ECOM_gambling', 'ECOM_gaming','ECOM_storage','ECOM_software']
x20_ = ['ECOM_other', 'ECOM_none', 'ECOM_music_spend', 'ECOM_video_spend', 'ECOM_ebook_spend'] 
x21_ = ['ECOM_podcast_spend', 'ECOM_news_spend', 'ECOM_giftcard_spend', 'ECOM_gambling_spend', 'ECOM_gaming_spend'] 
x21_2= ['ECOM_storage_spend','ECOM_software_spend', 'ECOM_other_spend', 'ECOM_totalspend']
x22_ = ['PURCH_clothing', 'PURCH_books', 'PURCH_gamestoys', 'PURCH_electronics']
x23_ = ['PURCH_houseware', 'PURCH_sports', 'PURCH_homeimprov','PURCH_automotive']
x23_2= ['PURCH_giftcard', 'PURCH_food', 'PURCH_prescription', 'PURCH_beauty', 'PURCH_cannabis', 'PURCH_other','PURCH_none']
x24_ = ['RIDE_spend', 'SRVC_food', 'SRVC_travel', 'SRVC_ticket', 'SRVC_fitness']
x24_2= ['SRVC_childcare', 'SRVC_photo', 'SRVC_other', 'SRVC_total_spend'] 
x25_ = ['PAY_onlineSRVC', 'PAY_wallet', 'PAY_credit', 'PAY_debit', 'PAY_etransfer', 'PAY_giftcard', 'PAY_rewards', 'PAY_other']
x26_ = ['REMOTE_work', 'ON_income', 'ON_income_main', 'ON_income_additional', 'ON_income_total']
x27_ = ['Household_income_quantile', 'Average_spending_online', 'Internet_income']
x27_2= ['Non_onlineShopper', 'OnlineShopper', 'Security_incident', 'vid_stream_user', 'gov_service_user', 'social_media_user', 'casual_sns_user', 'smartphone_user']

y_ = df['SM_USE_banking']

# %%
import matplotlib.pyplot as plt 
import seaborn as sns 
import numpy as np 

def pairing_plots(x):
    sns.pairplot(df, x_vars = x, y_vars = ['SM_USE_banking'])

# %%
pairing_plots(x1_)

# %%
pairing_plots(x1_2)

# %%
pairing_plots(x2_)

# %%
pairing_plots(x2_2)

# %%
pairing_plots(x3_)

# %%
pairing_plots(x4_)

# %%
pairing_plots(x5_)

# %%
pairing_plots(x6_)

# %%
pairing_plots(x6_2)

# %%
pairing_plots(x7_)

# %%
pairing_plots(x7_2)

# %%
pairing_plots(x8_)

# %%
pairing_plots(x8_2)

# %%
pairing_plots(x9_)

# %%
pairing_plots(x10_)

# %%
pairing_plots(x11_)

# %%
pairing_plots(x11_2)

# %%
pairing_plots(x13_)

# %%
pairing_plots(x14_)

# %%
pairing_plots(x15_)

# %%
pairing_plots(x16_)

# %%
pairing_plots(x17_)

# %%
pairing_plots(x18_)

# %%
pairing_plots(x19_)

# %%
pairing_plots(x20_)

# %%
pairing_plots(x21_)

# %%
pairing_plots(x21_2)

# %%
pairing_plots(x22_)

# %%
pairing_plots(x23_)

# %%
pairing_plots(x23_2)

# %%
pairing_plots(x24_)

# %%
pairing_plots(x24_2)

# %%
pairing_plots(x25_)

# %%
pairing_plots(x26_)

# %%
pairing_plots(x27_)

# %%
pairing_plots(x27_2)
